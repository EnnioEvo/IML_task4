# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#path that contains folder you want to copy
# %cp /content/gdrive/My\ Drive/Colab\ Notebooks/features_inception_resnet_inception_v3_finetune_COLAB.csv /content/
# %cp /content/gdrive/My\ Drive/Colab\ Notebooks/data/train_triplets.txt /content/
# %cp /content/gdrive/My\ Drive/Colab\ Notebooks/data/test_triplets.txt /content/

# %%
import itertools
import os
import pathlib
import matplotlib.pylab as plt
import numpy as np
import tensorflow as tf
import tensorflow_hub as hub
import pandas as pd
from PIL import Image
from math import ceil, floor
from timeit import default_timer as timer

# %%
np.random.seed(470)
AUTOTUNE = tf.data.experimental.AUTOTUNE
print("TF version:", tf.__version__)
print("Hub version:", hub.__version__)
print("Availables GPU:")
print(tf.config.list_physical_devices('GPU') if tf.config.list_physical_devices('GPU') != [] else 'No GPU available')
#os.environ["TFHUB_CACHE_DIR"] = "C:/Users/Ennio/AppData/Local/Temp/model"
# Out:
# TF version: 2.2.0
# Hub version: 0.8.0
# Availables GPU:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# read features
#features = np.array(pd.read_csv('/content/features_resnet.zip', compression='zip', delimiter=',', header=None))
features = np.array(pd.read_csv('/content/features_inception_resnet_inception_v3_finetune_COLAB.csv', delimiter=',', header=None))
BATCH_SIZE = 64
# read triplets
train_triplets_df = pd.read_csv('/content/train_triplets.txt', delimiter=' ', header=None)
test_triplets_df = pd.read_csv('/content/test_triplets.txt', delimiter=' ', header=None)
train_triplets_df.columns = ['A', 'B', 'C']
test_triplets_df.columns = ['A', 'B', 'C']

N_train = len(train_triplets_df.index)
N_test = len(test_triplets_df.index)

# %%
# swap half
N_train = len(train_triplets_df.index)
N_test = len(test_triplets_df.index)
swapped_train_triplets_df = train_triplets_df.iloc[:int(N_train / 2), :]
swapped_train_triplets_df.columns = ['A', 'C', 'B']
train_triplets_df = pd.concat((swapped_train_triplets_df, train_triplets_df.iloc[int(N_train / 2):, :]), sort=True)
# train_triplets_dict = {index: list(row) for index, row in train_triplets_df.iterrows()}

# create Y
Y_train_np = np.zeros((N_train,2))
Y_train_np[:,0] = (np.arange(N_train) >= int(N_train / 2)) * 1 
Y_train_np[:,1] = 1 - Y_train_np[:,0]


shuffle = True
if shuffle:
    rd_permutation = np.random.permutation(train_triplets_df.index)
    train_triplets_df = train_triplets_df.reindex(rd_permutation).set_index(np.arange(0, train_triplets_df.shape[0], 1))
    Y_train_np = Y_train_np[rd_permutation,:]
Y_train_ts = tf.constant(Y_train_np)

# %%
# build test and train
print()
def X_train_generator():
    for _, row in train_triplets_df.iterrows():
        yield features[row['A'], :], features[row['B'], :], features[row['C'], :]


def X_test_generator():
    for _, row in test_triplets_df.iterrows():
        yield features[row['A'], :], features[row['B'], :], features[row['C'], :]


input_shape = (1001,)
X_train = tf.data.Dataset.from_generator(X_train_generator,
                                         (tf.float32, tf.float32, tf.float32),
                                         output_shapes=(tf.TensorShape(input_shape),) * 3
                                         )

X_test = tf.data.Dataset.from_generator(X_test_generator,
                                        (tf.float32, tf.float32, tf.float32),
                                        output_shapes=(tf.TensorShape(input_shape),) * 3,
                                        ).batch(BATCH_SIZE)

Y_train = tf.data.Dataset.from_tensor_slices(Y_train_ts)
zipped_train = tf.data.Dataset.zip((X_train, Y_train)).batch(BATCH_SIZE).repeat()

# %%
# build the model
input_A = tf.keras.layers.Input(shape=input_shape, name='input_A'),
input_B = tf.keras.layers.Input(shape=input_shape, name='input_B'),
input_C = tf.keras.layers.Input(shape=input_shape, name='input_C'),

inputs_AB = [input_A[0], input_B[0]]
inputs_AC = [input_A[0], input_C[0]]

x_AB = tf.keras.layers.Concatenate(axis=1)(inputs_AB)
x_AC = tf.keras.layers.Concatenate(axis=1)(inputs_AC)

x_AB = tf.keras.layers.Dense(10, activation='relu')(x_AB)
x_AC = tf.keras.layers.Dense(10, activation='relu')(x_AC)

x = tf.keras.layers.Concatenate(axis=1)([x_AB, x_AC])
output = tf.keras.layers.Dense(2, activation='softmax')(x)

model = tf.keras.Model(inputs=[input_A, input_B, input_C], outputs=output, name='task3_model')

model.summary()
# Out:
# Model: "task3_model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_A (InputLayer)            [(None, 1001)]       0
# __________________________________________________________________________________________________
# input_B (InputLayer)            [(None, 1001)]       0
# __________________________________________________________________________________________________
# input_C (InputLayer)            [(None, 1001)]       0
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 2002)         0           input_A[0][0]
#                                                                  input_B[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 2002)         0           input_A[0][0]
#                                                                  input_C[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 10)           20030       concatenate_12[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 10)           20030       concatenate_13[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 20)           0           dense_12[0][0]
#                                                                  dense_13[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 2)            42          concatenate_14[0][0]
# ==================================================================================================
# Total params: 40,102
# Trainable params: 40,102
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#compile
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy']
              )
#callbacks
es = tf.keras.callbacks.EarlyStopping(monitor='accuracy', mode='max', verbose=1, patience=2, restore_best_weights=True)

#fit
print('Training started')
model.fit(zipped_train, epochs=10, steps_per_epoch=930, verbose=1, use_multiprocessing=True, callbacks=[es])
# Out:
# Training started
# Epoch 1/9
# 930/930 [==============================] - 26s 27ms/step - loss: 0.6627 - accuracy: 0.6738
# Epoch 2/9
# 930/930 [==============================] - 26s 27ms/step - loss: 0.6427 - accuracy: 0.7165
# Epoch 3/9
# 930/930 [==============================] - 25s 27ms/step - loss: 0.6352 - accuracy: 0.7337
# Epoch 4/9
# 930/930 [==============================] - 26s 28ms/step - loss: 0.6293 - accuracy: 0.7469
# Epoch 5/9
# 930/930 [==============================] - 26s 28ms/step - loss: 0.6253 - accuracy: 0.7561
# Epoch 6/9
# 930/930 [==============================] - 25s 27ms/step - loss: 0.6216 - accuracy: 0.7639
# Epoch 7/9
# 930/930 [==============================] - 25s 27ms/step - loss: 0.6198 - accuracy: 0.7678
# Epoch 8/9
# 930/930 [==============================] - 26s 28ms/step - loss: 0.6171 - accuracy: 0.7726
# Epoch 9/9
# 930/930 [==============================] - 25s 27ms/step - loss: 0.6150 - accuracy: 0.7767

# %%
#debug only
start = timer()
model.predict( [np.ones([BATCH_SIZE,2048]),]*3 )
end = timer()
elapsed = end - start
print(str(round(elapsed,2)) + " sec to predict a batch of " + str(BATCH_SIZE)
      + ", 59516 samples will be evaluated in " + str(round(59516/BATCH_SIZE*elapsed, 2)) + "sec")
# Out:
# 0.07 sec to predict a batch of 64, 59516 samples will be evaluated in 68.55sec

# %%
#function to predict batched dataset
def batch_predict(X, N):
  X_it = X.as_numpy_iterator()
  Y_batch = np.zeros([0,2])
  for n in range(0, N, BATCH_SIZE): #N = 59516 ==>
      start = timer()
      Y_batch = np.row_stack([Y_batch, model.predict(next(X_it))])
      end = timer()
      print('Predicted until ' + str(n) + ', ' + str(round(end-start,2)) + 's')
  print('Predicted')
  return Y_batch

#predict
Y_test = batch_predict(X_test, N_test)
pd.DataFrame(data=(Y_test[:,0]), columns=None, index=None).to_csv("sumbission_float.csv", index=None, header=None, float_format='%.2f')
pd.DataFrame(data=(Y_test[:,0]>0.5)*1, columns=None, index=None).to_csv("sumbission.csv", index=None, header=None)
print('Done')
# Out:
# Predicted until 0, 0.08s
# Predicted until 64, 0.05s
# Predicted until 128, 0.04s
# Predicted until 192, 0.04s
# Predicted until 256, 0.04s
# Predicted until 320, 0.06s
# Predicted until 384, 0.05s
# Predicted until 448, 0.04s
# Predicted until 512, 0.05s
# Predicted until 576, 0.05s
# Predicted until 640, 0.05s
# Predicted until 704, 0.05s
# Predicted until 768, 0.05s
# Predicted until 832, 0.05s
# Predicted until 896, 0.05s
# Predicted until 960, 0.05s
# Predicted until 1024, 0.05s
# Predicted until 1088, 0.05s
# Predicted until 1152, 0.05s
# Predicted until 1216, 0.05s
# Predicted until 1280, 0.05s
# Predicted until 1344, 0.05s
# Predicted until 1408, 0.04s
# Predicted until 1472, 0.05s
# Predicted until 1536, 0.05s
# Predicted until 1600, 0.05s
# Predicted until 1664, 0.05s
# Predicted until 1728, 0.05s
# Predicted until 1792, 0.05s
# Predicted until 1856, 0.05s
# Predicted until 1920, 0.05s
# Predicted until 1984, 0.04s
# Predicted until 2048, 0.04s
# Predicted until 2112, 0.05s
# Predicted until 2176, 0.05s
# Predicted until 2240, 0.04s
# Predicted until 2304, 0.04s
# Predicted until 2368, 0.05s
# Predicted until 2432, 0.05s
# Predicted until 2496, 0.05s
# Predicted until 2560, 0.04s
# Predicted until 2624, 0.04s
# Predicted until 2688, 0.05s
# Predicted until 2752, 0.05s
# Predicted until 2816, 0.05s
# Predicted until 2880, 0.04s
# Predicted until 2944, 0.05s
# Predicted until 3008, 0.05s
# Predicted until 3072, 0.05s
# Predicted until 3136, 0.06s
# Predicted until 3200, 0.05s
# Predicted until 3264, 0.05s
# Predicted until 3328, 0.05s
# Predicted until 3392, 0.05s
# Predicted until 3456, 0.05s
# Predicted until 3520, 0.04s
# Predicted until 3584, 0.05s
# Predicted until 3648, 0.05s
# Predicted until 3712, 0.05s
# Predicted until 3776, 0.05s
# Predicted until 3840, 0.05s
# Predicted until 3904, 0.05s
# Predicted until 3968, 0.05s
# Predicted until 4032, 0.05s
# Predicted until 4096, 0.06s
# Predicted until 4160, 0.05s
# Predicted until 4224, 0.06s
# Predicted until 4288, 0.05s
# Predicted until 4352, 0.05s
# Predicted until 4416, 0.05s
# Predicted until 4480, 0.05s
# Predicted until 4544, 0.05s
# Predicted until 4608, 0.04s
# Predicted until 4672, 0.05s
# Predicted until 4736, 0.05s
# Predicted until 4800, 0.05s
# Predicted until 4864, 0.04s
# Predicted until 4928, 0.04s
# Predicted until 4992, 0.05s
# Predicted until 5056, 0.05s
# Predicted until 5120, 0.04s
# Predicted until 5184, 0.04s
# Predicted until 5248, 0.04s
# Predicted until 5312, 0.05s
# Predicted until 5376, 0.05s
# Predicted until 5440, 0.06s
# Predicted until 5504, 0.04s
# Predicted until 5568, 0.05s
# Predicted until 5632, 0.05s
# Predicted until 5696, 0.05s
# Predicted until 5760, 0.05s
# Predicted until 5824, 0.05s
# Predicted until 5888, 0.05s
# Predicted until 5952, 0.05s
# Predicted until 6016, 0.05s
# Predicted until 6080, 0.06s
# Predicted until 6144, 0.05s
# Predicted until 6208, 0.04s
# Predicted until 6272, 0.05s
# Predicted until 6336, 0.04s
# Predicted until 6400, 0.04s
# Predicted until 6464, 0.04s
# Predicted until 6528, 0.04s
# Predicted until 6592, 0.05s
# Predicted until 6656, 0.05s
# Predicted until 6720, 0.04s
# Predicted until 6784, 0.05s
# Predicted until 6848, 0.05s
# Predicted until 6912, 0.05s
# Predicted until 6976, 0.04s
# Predicted until 7040, 0.04s
# Predicted until 7104, 0.04s
# Predicted until 7168, 0.04s
# Predicted until 7232, 0.05s
# Predicted until 7296, 0.05s
# Predicted until 7360, 0.05s
# Predicted until 7424, 0.04s
# Predicted until 7488, 0.05s
# Predicted until 7552, 0.05s
# Predicted until 7616, 0.05s
# Predicted until 7680, 0.04s
# Predicted until 7744, 0.04s
# Predicted until 7808, 0.04s
# Predicted until 7872, 0.05s
# Predicted until 7936, 0.04s
# Predicted until 8000, 0.04s
# Predicted until 8064, 0.04s
# Predicted until 8128, 0.04s
# Predicted until 8192, 0.06s
# Predicted until 8256, 0.05s
# Predicted until 8320, 0.05s
# Predicted until 8384, 0.04s
# Predicted until 8448, 0.04s
# Predicted until 8512, 0.05s
# Predicted until 8576, 0.05s
# Predicted until 8640, 0.05s
# Predicted until 8704, 0.05s
# Predicted until 8768, 0.04s
# Predicted until 8832, 0.05s
# Predicted until 8896, 0.05s
# Predicted until 8960, 0.04s
# Predicted until 9024, 0.05s
# Predicted until 9088, 0.05s
# Predicted until 9152, 0.05s
# Predicted until 9216, 0.04s
# Predicted until 9280, 0.05s
# Predicted until 9344, 0.05s
# Predicted until 9408, 0.05s
# Predicted until 9472, 0.05s
# Predicted until 9536, 0.04s
# Predicted until 9600, 0.06s
# Predicted until 9664, 0.05s
# Predicted until 9728, 0.06s
# Predicted until 9792, 0.05s
# Predicted until 9856, 0.05s
# Predicted until 9920, 0.05s
# Predicted until 9984, 0.06s
# Predicted until 10048, 0.05s
# Predicted until 10112, 0.05s
# Predicted until 10176, 0.05s
# Predicted until 10240, 0.05s
# Predicted until 10304, 0.05s
# Predicted until 10368, 0.05s
# Predicted until 10432, 0.05s
# Predicted until 10496, 0.05s
# Predicted until 10560, 0.05s
# Predicted until 10624, 0.04s
# Predicted until 10688, 0.04s
# Predicted until 10752, 0.04s
# Predicted until 10816, 0.05s
# Predicted until 10880, 0.05s
# Predicted until 10944, 0.05s
# Predicted until 11008, 0.05s
# Predicted until 11072, 0.05s
# Predicted until 11136, 0.05s
# Predicted until 11200, 0.05s
# Predicted until 11264, 0.05s
# Predicted until 11328, 0.04s
# Predicted until 11392, 0.04s
# Predicted until 11456, 0.05s
# Predicted until 11520, 0.05s
# Predicted until 11584, 0.06s
# Predicted until 11648, 0.05s
# Predicted until 11712, 0.05s
# Predicted until 11776, 0.05s
# Predicted until 11840, 0.04s
# Predicted until 11904, 0.04s
# Predicted until 11968, 0.04s
# Predicted until 12032, 0.05s
# Predicted until 12096, 0.05s
# Predicted until 12160, 0.05s
# Predicted until 12224, 0.06s
# Predicted until 12288, 0.05s
# Predicted until 12352, 0.04s
# Predicted until 12416, 0.04s
# Predicted until 12480, 0.05s
# Predicted until 12544, 0.05s
# Predicted until 12608, 0.05s
# Predicted until 12672, 0.04s
# Predicted until 12736, 0.04s
# Predicted until 12800, 0.05s
# Predicted until 12864, 0.05s
# Predicted until 12928, 0.05s
# Predicted until 12992, 0.05s
# Predicted until 13056, 0.04s
# Predicted until 13120, 0.04s
# Predicted until 13184, 0.04s
# Predicted until 13248, 0.05s
# Predicted until 13312, 0.04s
# Predicted until 13376, 0.05s
# Predicted until 13440, 0.05s
# Predicted until 13504, 0.05s
# Predicted until 13568, 0.05s
# Predicted until 13632, 0.05s
# Predicted until 13696, 0.04s
# Predicted until 13760, 0.05s
# Predicted until 13824, 0.04s
# Predicted until 13888, 0.05s
# Predicted until 13952, 0.04s
# Predicted until 14016, 0.05s
# Predicted until 14080, 0.04s
# Predicted until 14144, 0.04s
# Predicted until 14208, 0.05s
# Predicted until 14272, 0.05s
# Predicted until 14336, 0.05s
# Predicted until 14400, 0.06s
# Predicted until 14464, 0.06s
# Predicted until 14528, 0.05s
# Predicted until 14592, 0.05s
# Predicted until 14656, 0.05s
# Predicted until 14720, 0.04s
# Predicted until 14784, 0.05s
# Predicted until 14848, 0.04s
# Predicted until 14912, 0.04s
# Predicted until 14976, 0.06s
# Predicted until 15040, 0.06s
# Predicted until 15104, 0.05s
# Predicted until 15168, 0.05s
# Predicted until 15232, 0.05s
# Predicted until 15296, 0.06s
# Predicted until 15360, 0.05s
# Predicted until 15424, 0.05s
# Predicted until 15488, 0.05s
# Predicted until 15552, 0.05s
# Predicted until 15616, 0.05s
# Predicted until 15680, 0.05s
# Predicted until 15744, 0.05s
# Predicted until 15808, 0.05s
# Predicted until 15872, 0.05s
# Predicted until 15936, 0.05s
# Predicted until 16000, 0.05s
# Predicted until 16064, 0.04s
# Predicted until 16128, 0.04s
# Predicted until 16192, 0.04s
# Predicted until 16256, 0.06s
# Predicted until 16320, 0.05s
# Predicted until 16384, 0.05s
# Predicted until 16448, 0.05s
# Predicted until 16512, 0.05s
# Predicted until 16576, 0.05s
# Predicted until 16640, 0.05s
# Predicted until 16704, 0.04s
# Predicted until 16768, 0.06s
# Predicted until 16832, 0.05s
# Predicted until 16896, 0.05s
# Predicted until 16960, 0.05s
# Predicted until 17024, 0.05s
# Predicted until 17088, 0.05s
# Predicted until 17152, 0.04s
# Predicted until 17216, 0.05s
# Predicted until 17280, 0.05s
# Predicted until 17344, 0.05s
# Predicted until 17408, 0.04s
# Predicted until 17472, 0.04s
# Predicted until 17536, 0.05s
# Predicted until 17600, 0.05s
# Predicted until 17664, 0.05s
# Predicted until 17728, 0.06s
# Predicted until 17792, 0.04s
# Predicted until 17856, 0.05s
# Predicted until 17920, 0.05s
# Predicted until 17984, 0.05s
# Predicted until 18048, 0.05s
# Predicted until 18112, 0.05s
# Predicted until 18176, 0.04s
# Predicted until 18240, 0.05s
# Predicted until 18304, 0.05s
# Predicted until 18368, 0.05s
# Predicted until 18432, 0.05s
# Predicted until 18496, 0.04s
# Predicted until 18560, 0.04s
# Predicted until 18624, 0.05s
# Predicted until 18688, 0.05s
# Predicted until 18752, 0.05s
# Predicted until 18816, 0.04s
# Predicted until 18880, 0.05s
# Predicted until 18944, 0.05s
# Predicted until 19008, 0.05s
# Predicted until 19072, 0.05s
# Predicted until 19136, 0.05s
# Predicted until 19200, 0.05s
# Predicted until 19264, 0.04s
# Predicted until 19328, 0.04s
# Predicted until 19392, 0.05s
# Predicted until 19456, 0.05s
# Predicted until 19520, 0.04s
# Predicted until 19584, 0.06s
# Predicted until 19648, 0.05s
# Predicted until 19712, 0.05s
# Predicted until 19776, 0.05s
# Predicted until 19840, 0.04s
# Predicted until 19904, 0.04s
# Predicted until 19968, 0.05s
# Predicted until 20032, 0.05s
# Predicted until 20096, 0.05s
# Predicted until 20160, 0.05s
# Predicted until 20224, 0.04s
# Predicted until 20288, 0.05s
# Predicted until 20352, 0.06s
# Predicted until 20416, 0.05s
# Predicted until 20480, 0.04s
# Predicted until 20544, 0.05s
# Predicted until 20608, 0.04s
# Predicted until 20672, 0.05s
# Predicted until 20736, 0.05s
# Predicted until 20800, 0.05s
# Predicted until 20864, 0.04s
# Predicted until 20928, 0.05s
# Predicted until 20992, 0.05s
# Predicted until 21056, 0.05s
# Predicted until 21120, 0.04s
# Predicted until 21184, 0.04s
# Predicted until 21248, 0.04s
# Predicted until 21312, 0.05s
# Predicted until 21376, 0.05s
# Predicted until 21440, 0.05s
# Predicted until 21504, 0.04s
# Predicted until 21568, 0.05s
# Predicted until 21632, 0.05s
# Predicted until 21696, 0.05s
# Predicted until 21760, 0.05s
# Predicted until 21824, 0.05s
# Predicted until 21888, 0.05s
# Predicted until 21952, 0.05s
# Predicted until 22016, 0.05s
# Predicted until 22080, 0.04s
# Predicted until 22144, 0.04s
# Predicted until 22208, 0.04s
# Predicted until 22272, 0.05s
# Predicted until 22336, 0.05s
# Predicted until 22400, 0.04s
# Predicted until 22464, 0.04s
# Predicted until 22528, 0.04s
# Predicted until 22592, 0.05s
# Predicted until 22656, 0.05s
# Predicted until 22720, 0.04s
# Predicted until 22784, 0.04s
# Predicted until 22848, 0.04s
# Predicted until 22912, 0.05s
# Predicted until 22976, 0.05s
# Predicted until 23040, 0.05s
# Predicted until 23104, 0.05s
# Predicted until 23168, 0.05s
# Predicted until 23232, 0.05s
# Predicted until 23296, 0.05s
# Predicted until 23360, 0.05s
# Predicted until 23424, 0.04s
# Predicted until 23488, 0.05s
# Predicted until 23552, 0.05s
# Predicted until 23616, 0.05s
# Predicted until 23680, 0.05s
# Predicted until 23744, 0.04s
# Predicted until 23808, 0.05s
# Predicted until 23872, 0.06s
# Predicted until 23936, 0.05s
# Predicted until 24000, 0.05s
# Predicted until 24064, 0.05s
# Predicted until 24128, 0.05s
# Predicted until 24192, 0.05s
# Predicted until 24256, 0.05s
# Predicted until 24320, 0.05s
# Predicted until 24384, 0.05s
# Predicted until 24448, 0.06s
# Predicted until 24512, 0.06s
# Predicted until 24576, 0.05s
# Predicted until 24640, 0.05s
# Predicted until 24704, 0.05s
# Predicted until 24768, 0.05s
# Predicted until 24832, 0.05s
# Predicted until 24896, 0.05s
# Predicted until 24960, 0.05s
# Predicted until 25024, 0.05s
# Predicted until 25088, 0.05s
# Predicted until 25152, 0.05s
# Predicted until 25216, 0.05s
# Predicted until 25280, 0.05s
# Predicted until 25344, 0.04s
# Predicted until 25408, 0.05s
# Predicted until 25472, 0.05s
# Predicted until 25536, 0.05s
# Predicted until 25600, 0.05s
# Predicted until 25664, 0.04s
# Predicted until 25728, 0.06s
# Predicted until 25792, 0.05s
# Predicted until 25856, 0.05s
# Predicted until 25920, 0.05s
# Predicted until 25984, 0.05s
# Predicted until 26048, 0.05s
# Predicted until 26112, 0.05s
# Predicted until 26176, 0.05s
# Predicted until 26240, 0.06s
# Predicted until 26304, 0.05s
# Predicted until 26368, 0.04s
# Predicted until 26432, 0.05s
# Predicted until 26496, 0.04s
# Predicted until 26560, 0.05s
# Predicted until 26624, 0.04s
# Predicted until 26688, 0.05s
# Predicted until 26752, 0.04s
# Predicted until 26816, 0.04s
# Predicted until 26880, 0.05s
# Predicted until 26944, 0.05s
# Predicted until 27008, 0.05s
# Predicted until 27072, 0.05s
# Predicted until 27136, 0.05s
# Predicted until 27200, 0.05s
# Predicted until 27264, 0.04s
# Predicted until 27328, 0.05s
# Predicted until 27392, 0.05s
# Predicted until 27456, 0.04s
# Predicted until 27520, 0.05s
# Predicted until 27584, 0.05s
# Predicted until 27648, 0.06s
# Predicted until 27712, 0.05s
# Predicted until 27776, 0.05s
# Predicted until 27840, 0.05s
# Predicted until 27904, 0.04s
# Predicted until 27968, 0.05s
# Predicted until 28032, 0.04s
# Predicted until 28096, 0.05s
# Predicted until 28160, 0.05s
# Predicted until 28224, 0.05s
# Predicted until 28288, 0.05s
# Predicted until 28352, 0.05s
# Predicted until 28416, 0.05s
# Predicted until 28480, 0.05s
# Predicted until 28544, 0.05s
# Predicted until 28608, 0.05s
# Predicted until 28672, 0.04s
# Predicted until 28736, 0.05s
# Predicted until 28800, 0.05s
# Predicted until 28864, 0.21s
# Predicted until 28928, 0.05s
# Predicted until 28992, 0.05s
# Predicted until 29056, 0.05s
# Predicted until 29120, 0.04s
# Predicted until 29184, 0.05s
# Predicted until 29248, 0.04s
# Predicted until 29312, 0.05s
# Predicted until 29376, 0.05s
# Predicted until 29440, 0.04s
# Predicted until 29504, 0.05s
# Predicted until 29568, 0.05s
# Predicted until 29632, 0.05s
# Predicted until 29696, 0.05s
# Predicted until 29760, 0.05s
# Predicted until 29824, 0.05s
# Predicted until 29888, 0.05s
# Predicted until 29952, 0.05s
# Predicted until 30016, 0.05s
# Predicted until 30080, 0.05s
# Predicted until 30144, 0.06s
# Predicted until 30208, 0.05s
# Predicted until 30272, 0.05s
# Predicted until 30336, 0.05s
# Predicted until 30400, 0.05s
# Predicted until 30464, 0.05s
# Predicted until 30528, 0.04s
# Predicted until 30592, 0.05s
# Predicted until 30656, 0.05s
# Predicted until 30720, 0.04s
# Predicted until 30784, 0.05s
# Predicted until 30848, 0.04s
# Predicted until 30912, 0.05s
# Predicted until 30976, 0.05s
# Predicted until 31040, 0.05s
# Predicted until 31104, 0.05s
# Predicted until 31168, 0.04s
# Predicted until 31232, 0.05s
# Predicted until 31296, 0.05s
# Predicted until 31360, 0.05s
# Predicted until 31424, 0.05s
# Predicted until 31488, 0.05s
# Predicted until 31552, 0.05s
# Predicted until 31616, 0.05s
# Predicted until 31680, 0.04s
# Predicted until 31744, 0.05s
# Predicted until 31808, 0.04s
# Predicted until 31872, 0.05s
# Predicted until 31936, 0.04s
# Predicted until 32000, 0.05s
# Predicted until 32064, 0.05s
# Predicted until 32128, 0.05s
# Predicted until 32192, 0.04s
# Predicted until 32256, 0.05s
# Predicted until 32320, 0.05s
# Predicted until 32384, 0.06s
# Predicted until 32448, 0.05s
# Predicted until 32512, 0.05s
# Predicted until 32576, 0.05s
# Predicted until 32640, 0.05s
# Predicted until 32704, 0.05s
# Predicted until 32768, 0.05s
# Predicted until 32832, 0.05s
# Predicted until 32896, 0.05s
# Predicted until 32960, 0.05s
# Predicted until 33024, 0.05s
# Predicted until 33088, 0.05s
# Predicted until 33152, 0.05s
# Predicted until 33216, 0.04s
# Predicted until 33280, 0.05s
# Predicted until 33344, 0.06s
# Predicted until 33408, 0.05s
# Predicted until 33472, 0.05s
# Predicted until 33536, 0.05s
# Predicted until 33600, 0.05s
# Predicted until 33664, 0.05s
# Predicted until 33728, 0.06s
# Predicted until 33792, 0.04s
# Predicted until 33856, 0.05s
# Predicted until 33920, 0.05s
# Predicted until 33984, 0.05s
# Predicted until 34048, 0.05s
# Predicted until 34112, 0.05s
# Predicted until 34176, 0.05s
# Predicted until 34240, 0.04s
# Predicted until 34304, 0.05s
# Predicted until 34368, 0.05s
# Predicted until 34432, 0.04s
# Predicted until 34496, 0.04s
# Predicted until 34560, 0.05s
# Predicted until 34624, 0.05s
# Predicted until 34688, 0.05s
# Predicted until 34752, 0.04s
# Predicted until 34816, 0.04s
# Predicted until 34880, 0.05s
# Predicted until 34944, 0.06s
# Predicted until 35008, 0.05s
# Predicted until 35072, 0.05s
# Predicted until 35136, 0.05s
# Predicted until 35200, 0.05s
# Predicted until 35264, 0.05s
# Predicted until 35328, 0.05s
# Predicted until 35392, 0.04s
# Predicted until 35456, 0.04s
# Predicted until 35520, 0.06s
# Predicted until 35584, 0.05s
# Predicted until 35648, 0.04s
# Predicted until 35712, 0.04s
# Predicted until 35776, 0.04s
# Predicted until 35840, 0.04s
# Predicted until 35904, 0.05s
# Predicted until 35968, 0.05s
# Predicted until 36032, 0.05s
# Predicted until 36096, 0.05s
# Predicted until 36160, 0.06s
# Predicted until 36224, 0.05s
# Predicted until 36288, 0.05s
# Predicted until 36352, 0.05s
# Predicted until 36416, 0.04s
# Predicted until 36480, 0.05s
# Predicted until 36544, 0.05s
# Predicted until 36608, 0.05s
# Predicted until 36672, 0.05s
# Predicted until 36736, 0.05s
# Predicted until 36800, 0.05s
# Predicted until 36864, 0.04s
# Predicted until 36928, 0.05s
# Predicted until 36992, 0.04s
# Predicted until 37056, 0.04s
# Predicted until 37120, 0.05s
# Predicted until 37184, 0.05s
# Predicted until 37248, 0.05s
# Predicted until 37312, 0.05s
# Predicted until 37376, 0.06s
# Predicted until 37440, 0.04s
# Predicted until 37504, 0.05s
# Predicted until 37568, 0.05s
# Predicted until 37632, 0.05s
# Predicted until 37696, 0.05s
# Predicted until 37760, 0.04s
# Predicted until 37824, 0.05s
# Predicted until 37888, 0.05s
# Predicted until 37952, 0.04s
# Predicted until 38016, 0.05s
# Predicted until 38080, 0.04s
# Predicted until 38144, 0.05s
# Predicted until 38208, 0.04s
# Predicted until 38272, 0.05s
# Predicted until 38336, 0.05s
# Predicted until 38400, 0.04s
# Predicted until 38464, 0.05s
# Predicted until 38528, 0.05s
# Predicted until 38592, 0.05s
# Predicted until 38656, 0.05s
# Predicted until 38720, 0.05s
# Predicted until 38784, 0.05s
# Predicted until 38848, 0.05s
# Predicted until 38912, 0.05s
# Predicted until 38976, 0.05s
# Predicted until 39040, 0.05s
# Predicted until 39104, 0.05s
# Predicted until 39168, 0.04s
# Predicted until 39232, 0.06s
# Predicted until 39296, 0.05s
# Predicted until 39360, 0.05s
# Predicted until 39424, 0.05s
# Predicted until 39488, 0.04s
# Predicted until 39552, 0.04s
# Predicted until 39616, 0.06s
# Predicted until 39680, 0.04s
# Predicted until 39744, 0.04s
# Predicted until 39808, 0.05s
# Predicted until 39872, 0.04s
# Predicted until 39936, 0.05s
# Predicted until 40000, 0.05s
# Predicted until 40064, 0.05s
# Predicted until 40128, 0.05s
# Predicted until 40192, 0.05s
# Predicted until 40256, 0.05s
# Predicted until 40320, 0.05s
# Predicted until 40384, 0.05s
# Predicted until 40448, 0.06s
# Predicted until 40512, 0.06s
# Predicted until 40576, 0.05s
# Predicted until 40640, 0.05s
# Predicted until 40704, 0.05s
# Predicted until 40768, 0.05s
# Predicted until 40832, 0.05s
# Predicted until 40896, 0.06s
# Predicted until 40960, 0.05s
# Predicted until 41024, 0.05s
# Predicted until 41088, 0.05s
# Predicted until 41152, 0.05s
# Predicted until 41216, 0.05s
# Predicted until 41280, 0.05s
# Predicted until 41344, 0.05s
# Predicted until 41408, 0.05s
# Predicted until 41472, 0.05s
# Predicted until 41536, 0.05s
# Predicted until 41600, 0.05s
# Predicted until 41664, 0.05s
# Predicted until 41728, 0.05s
# Predicted until 41792, 0.05s
# Predicted until 41856, 0.05s
# Predicted until 41920, 0.05s
# Predicted until 41984, 0.05s
# Predicted until 42048, 0.05s
# Predicted until 42112, 0.05s
# Predicted until 42176, 0.05s
# Predicted until 42240, 0.05s
# Predicted until 42304, 0.05s
# Predicted until 42368, 0.05s
# Predicted until 42432, 0.05s
# Predicted until 42496, 0.05s
# Predicted until 42560, 0.05s
# Predicted until 42624, 0.05s
# Predicted until 42688, 0.05s
# Predicted until 42752, 0.05s
# Predicted until 42816, 0.05s
# Predicted until 42880, 0.06s
# Predicted until 42944, 0.05s
# Predicted until 43008, 0.05s
# Predicted until 43072, 0.05s
# Predicted until 43136, 0.05s
# Predicted until 43200, 0.06s
# Predicted until 43264, 0.05s
# Predicted until 43328, 0.06s
# Predicted until 43392, 0.06s
# Predicted until 43456, 0.05s
# Predicted until 43520, 0.06s
# Predicted until 43584, 0.05s
# Predicted until 43648, 0.05s
# Predicted until 43712, 0.05s
# Predicted until 43776, 0.06s
# Predicted until 43840, 0.06s
# Predicted until 43904, 0.05s
# Predicted until 43968, 0.05s
# Predicted until 44032, 0.05s
# Predicted until 44096, 0.05s
# Predicted until 44160, 0.06s
# Predicted until 44224, 0.05s
# Predicted until 44288, 0.05s
# Predicted until 44352, 0.05s
# Predicted until 44416, 0.06s
# Predicted until 44480, 0.05s
# Predicted until 44544, 0.05s
# Predicted until 44608, 0.05s
# Predicted until 44672, 0.05s
# Predicted until 44736, 0.06s
# Predicted until 44800, 0.05s
# Predicted until 44864, 0.04s
# Predicted until 44928, 0.05s
# Predicted until 44992, 0.05s
# Predicted until 45056, 0.05s
# Predicted until 45120, 0.05s
# Predicted until 45184, 0.05s
# Predicted until 45248, 0.04s
# Predicted until 45312, 0.05s
# Predicted until 45376, 0.05s
# Predicted until 45440, 0.05s
# Predicted until 45504, 0.05s
# Predicted until 45568, 0.05s
# Predicted until 45632, 0.05s
# Predicted until 45696, 0.05s
# Predicted until 45760, 0.05s
# Predicted until 45824, 0.05s
# Predicted until 45888, 0.04s
# Predicted until 45952, 0.06s
# Predicted until 46016, 0.05s
# Predicted until 46080, 0.05s
# Predicted until 46144, 0.05s
# Predicted until 46208, 0.05s
# Predicted until 46272, 0.05s
# Predicted until 46336, 0.05s
# Predicted until 46400, 0.05s
# Predicted until 46464, 0.05s
# Predicted until 46528, 0.05s
# Predicted until 46592, 0.06s
# Predicted until 46656, 0.05s
# Predicted until 46720, 0.05s
# Predicted until 46784, 0.05s
# Predicted until 46848, 0.05s
# Predicted until 46912, 0.05s
# Predicted until 46976, 0.05s
# Predicted until 47040, 0.05s
# Predicted until 47104, 0.05s
# Predicted until 47168, 0.05s
# Predicted until 47232, 0.05s
# Predicted until 47296, 0.05s
# Predicted until 47360, 0.05s
# Predicted until 47424, 0.05s
# Predicted until 47488, 0.05s
# Predicted until 47552, 0.05s
# Predicted until 47616, 0.05s
# Predicted until 47680, 0.05s
# Predicted until 47744, 0.05s
# Predicted until 47808, 0.05s
# Predicted until 47872, 0.05s
# Predicted until 47936, 0.05s
# Predicted until 48000, 0.05s
# Predicted until 48064, 0.05s
# Predicted until 48128, 0.05s
# Predicted until 48192, 0.05s
# Predicted until 48256, 0.05s
# Predicted until 48320, 0.05s
# Predicted until 48384, 0.05s
# Predicted until 48448, 0.06s
# Predicted until 48512, 0.06s
# Predicted until 48576, 0.05s
# Predicted until 48640, 0.05s
# Predicted until 48704, 0.05s
# Predicted until 48768, 0.05s
# Predicted until 48832, 0.05s
# Predicted until 48896, 0.05s
# Predicted until 48960, 0.05s
# Predicted until 49024, 0.05s
# Predicted until 49088, 0.05s
# Predicted until 49152, 0.05s
# Predicted until 49216, 0.05s
# Predicted until 49280, 0.05s
# Predicted until 49344, 0.05s
# Predicted until 49408, 0.05s
# Predicted until 49472, 0.05s
# Predicted until 49536, 0.05s
# Predicted until 49600, 0.05s
# Predicted until 49664, 0.05s
# Predicted until 49728, 0.05s
# Predicted until 49792, 0.05s
# Predicted until 49856, 0.05s
# Predicted until 49920, 0.05s
# Predicted until 49984, 0.05s
# Predicted until 50048, 0.05s
# Predicted until 50112, 0.05s
# Predicted until 50176, 0.05s
# Predicted until 50240, 0.05s
# Predicted until 50304, 0.06s
# Predicted until 50368, 0.04s
# Predicted until 50432, 0.05s
# Predicted until 50496, 0.05s
# Predicted until 50560, 0.05s
# Predicted until 50624, 0.05s
# Predicted until 50688, 0.05s
# Predicted until 50752, 0.05s
# Predicted until 50816, 0.05s
# Predicted until 50880, 0.06s
# Predicted until 50944, 0.05s
# Predicted until 51008, 0.05s
# Predicted until 51072, 0.06s
# Predicted until 51136, 0.05s
# Predicted until 51200, 0.05s
# Predicted until 51264, 0.05s
# Predicted until 51328, 0.05s
# Predicted until 51392, 0.05s
# Predicted until 51456, 0.05s
# Predicted until 51520, 0.05s
# Predicted until 51584, 0.05s
# Predicted until 51648, 0.05s
# Predicted until 51712, 0.05s
# Predicted until 51776, 0.05s
# Predicted until 51840, 0.05s
# Predicted until 51904, 0.05s
# Predicted until 51968, 0.05s
# Predicted until 52032, 0.05s
# Predicted until 52096, 0.05s
# Predicted until 52160, 0.05s
# Predicted until 52224, 0.05s
# Predicted until 52288, 0.05s
# Predicted until 52352, 0.05s
# Predicted until 52416, 0.05s
# Predicted until 52480, 0.05s
# Predicted until 52544, 0.05s
# Predicted until 52608, 0.05s
# Predicted until 52672, 0.06s
# Predicted until 52736, 0.07s
# Predicted until 52800, 0.05s
# Predicted until 52864, 0.05s
# Predicted until 52928, 0.05s
# Predicted until 52992, 0.06s
# Predicted until 53056, 0.05s
# Predicted until 53120, 0.05s
# Predicted until 53184, 0.06s
# Predicted until 53248, 0.05s
# Predicted until 53312, 0.05s
# Predicted until 53376, 0.06s
# Predicted until 53440, 0.05s
# Predicted until 53504, 0.05s
# Predicted until 53568, 0.05s
# Predicted until 53632, 0.05s
# Predicted until 53696, 0.05s
# Predicted until 53760, 0.05s
# Predicted until 53824, 0.05s
# Predicted until 53888, 0.05s
# Predicted until 53952, 0.06s
# Predicted until 54016, 0.05s
# Predicted until 54080, 0.05s
# Predicted until 54144, 0.05s
# Predicted until 54208, 0.05s
# Predicted until 54272, 0.05s
# Predicted until 54336, 0.05s
# Predicted until 54400, 0.05s
# Predicted until 54464, 0.05s
# Predicted until 54528, 0.05s
# Predicted until 54592, 0.05s
# Predicted until 54656, 0.05s
# Predicted until 54720, 0.05s
# Predicted until 54784, 0.05s
# Predicted until 54848, 0.05s
# Predicted until 54912, 0.05s
# Predicted until 54976, 0.06s
# Predicted until 55040, 0.05s
# Predicted until 55104, 0.05s
# Predicted until 55168, 0.05s
# Predicted until 55232, 0.05s
# Predicted until 55296, 0.05s
# Predicted until 55360, 0.05s
# Predicted until 55424, 0.05s
# Predicted until 55488, 0.05s
# Predicted until 55552, 0.05s
# Predicted until 55616, 0.05s
# Predicted until 55680, 0.05s
# Predicted until 55744, 0.05s
# Predicted until 55808, 0.05s
# Predicted until 55872, 0.05s
# Predicted until 55936, 0.05s
# Predicted until 56000, 0.05s
# Predicted until 56064, 0.05s
# Predicted until 56128, 0.05s
# Predicted until 56192, 0.05s
# Predicted until 56256, 0.05s
# Predicted until 56320, 0.06s
# Predicted until 56384, 0.05s
# Predicted until 56448, 0.06s
# Predicted until 56512, 0.06s
# Predicted until 56576, 0.05s
# Predicted until 56640, 0.05s
# Predicted until 56704, 0.05s
# Predicted until 56768, 0.05s
# Predicted until 56832, 0.05s
# Predicted until 56896, 0.05s
# Predicted until 56960, 0.05s
# Predicted until 57024, 0.06s
# Predicted until 57088, 0.07s
# Predicted until 57152, 0.06s
# Predicted until 57216, 0.05s
# Predicted until 57280, 0.05s
# Predicted until 57344, 0.06s
# Predicted until 57408, 0.05s
# Predicted until 57472, 0.05s
# Predicted until 57536, 0.06s
# Predicted until 57600, 0.05s
# Predicted until 57664, 0.05s
# Predicted until 57728, 0.06s
# Predicted until 57792, 0.05s
# Predicted until 57856, 0.05s
# Predicted until 57920, 0.05s
# Predicted until 57984, 0.05s
# Predicted until 58048, 0.05s
# Predicted until 58112, 0.05s
# Predicted until 58176, 0.05s
# Predicted until 58240, 0.05s
# Predicted until 58304, 0.05s
# Predicted until 58368, 0.05s
# Predicted until 58432, 0.05s
# Predicted until 58496, 0.05s
# Predicted until 58560, 0.05s
# Predicted until 58624, 0.05s
# Predicted until 58688, 0.05s
# Predicted until 58752, 0.05s
# Predicted until 58816, 0.05s
# Predicted until 58880, 0.05s
# Predicted until 58944, 0.05s
# Predicted until 59008, 0.05s
# Predicted until 59072, 0.05s
# Predicted until 59136, 0.05s
# Predicted until 59200, 0.05s
# Predicted until 59264, 0.05s
# Predicted until 59328, 0.05s
# Predicted until 59392, 0.05s
# Predicted until 59456, 0.05s
# Predicted until 59520, 0.07s
# Predicted
# Done
